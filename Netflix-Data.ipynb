# %% [markdown]
# Netflix DataSet
#
# Big-Data Analysis with Python

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\parag\\OneDrive\\Desktop\\Anudeep Data visualisation\\Jupyter Data Analyst Projects\\netflix1.csv")

# %%
data
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# Getting Some Basic Information About The Dataset

# %% [markdown]
# 1.head()

# %%
# to show top-5 records of the dataset
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# 2.tail()

# %%
# to show bottom-5 records of the dataset
data.tail()
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789  06-07-2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %% [markdown]
# 3. Shape

# %%
# to show the No. of Row And Column in dataset
data.shape
# Out:
# (8790, 10)

# %% [markdown]
# 4. size

# %%
# to show the No. total value(elements) in the dataset
data.size
# Out:
# 87900

# %% [markdown]
# Exploring The Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %% [markdown]
# There re not null and the data is completed

# %%
data.isna().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %% [markdown]
# There is no nan value

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There is no duplicated value in data

# %% [markdown]
# CLEANING THE DATA

# %%
data.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %% [markdown]
# The date is object datatype will convert to datetime

# %%
data.rename(columns={'date_added':'Date',"listed_in":"category"},inplace=True)

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country       Date  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                             category
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
data['Date'] = pd.to_datetime(data['Date']) # Issue

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   Date          8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   category      8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
data.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [raw]
# ANALYSIS AND VISUALIZATION

# %% [markdown]
# THE MOVE TYPE

# %%
showtype=data['type'].value_counts().reset_index()

# %% [markdown]
# From column type show we have from movie 6126 and tv show 2664

# %%
showtype
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %% [markdown]
# Different Between TV shows and Movies

# %%
plt.figure(figsize=(20,6))
plt.pie(showtype['count'],labels=['Movie','TVshow'],autopct='%1.3f%%',explode=[0,0.1])
plt.show()

# %%
data.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country       Date  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                             category
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# The differnce between director is given or not

# %%
directors = data['director'].value_counts()
directors.head(10)
# Out:
# director
# Not Given                 2588
# Rajiv Chilaka               20
# Alastair Fothergill         18
# Raúl Campos, Jan Suter      18
# Marcus Raboy                16
# Suhas Kadav                 16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Youssef Chahine             12
# Jay Chapman                 12
# Name: count, dtype: int64

# %%
given_directors = directors.sum() - directors[0]
print(f'given directors = {given_directors}')
# Out:
# given directors = 6202
# C:\Users\parag\AppData\Local\Temp\ipykernel_26484\4101068066.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   given_directors = directors.sum() - directors[0]

# %% [markdown]
# The Number of Movies or director Doing

# %%
directors = data.groupby(['director', 'type'])['director'].value_counts().reset_index().head(15)
directors
# Out:
#                           director   type  count
# 0                      A. L. Vijay  Movie      2
# 1                     A. Raajdheep  Movie      1
# 2                        A. Salaam  Movie      1
# 3                  A.R. Murugadoss  Movie      2
# 4                  Aadish Keluskar  Movie      1
# 5                     Aamir Bashir  Movie      1
# 6                       Aamir Khan  Movie      1
# 7                       Aanand Rai  Movie      1
# 8                      Aaron Burns  Movie      1
# 9   Aaron Hancox, Michael McNamara  Movie      1
# 10      Aaron Hann, Mario Miscione  Movie      1
# 11                    Aaron Lieber  Movie      1
# 12             Aaron Nee, Adam Nee  Movie      1
# 13                    Aaron Sorkin  Movie      2
# 14                   Aaron Woodley  Movie      1

# %% [markdown]
# Number of movies or tv shows to 15 director

# %%
plt.figure(figsize=(20,6))
plt.bar(directors['director'],directors['count'],color='darkred')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Country Column

# %%
country = data['country'].value_counts().reset_index().sort_values(by='count',ascending = False).head(60)
country
# Out:
#                  country  count
# 0          United States   3240
# 1                  India   1057
# 2         United Kingdom    638
# 3               Pakistan    421
# 4              Not Given    287
# 5                 Canada    271
# 6                  Japan    259
# 7            South Korea    214
# 8                 France    213
# 9                  Spain    182
# 10                Mexico    138
# 11                 Egypt    123
# 12             Australia    114
# 13                Turkey    112
# 14               Nigeria    105
# 15               Germany    104
# 16                 China    100
# 17                Brazil     88
# 18                Taiwan     86
# 19             Indonesia     86
# 20           Philippines     83
# 21             Hong Kong     79
# 22             Argentina     76
# 23                 Italy     66
# 24              Thailand     66
# 25              Colombia     42
# 26          South Africa     42
# 27               Denmark     30
# ...

# %% [markdown]
# This graph show the more shows is in US
#
# Now determine the TVshow and movie in the every country

# %%
plt.figure(figsize=(20,6))
plt.plot(country['country'],country['count'],color='darkred')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Top 10 Country

# %%
country = data['country'].value_counts().reset_index().sort_values(by='count',ascending = False).head(10)
country
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %% [markdown]
# Number of Movies in Country

# %%
plt.figure(figsize=(20,8))
plt.title('Top 10 countries')
sns.barplot(x='country',y='count',data=country)
plt.xlabel('Country')
plt.ylabel('No of Movies')
# Out:
# Text(0, 0.5, 'No of Movies')

# %% [markdown]
# US have the greatest number of movie between top 10 Country

# %%
top10_country=country.sort_values(by='count',ascending=False).head(10)
top10_country
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %%
sns.barplot(data=top10_country,x='country',y='count',hue=data['type'],alpha=0.8,width=0.6)
plt.ylabel('Count')
plt.xlabel('Contries')
plt.title('Top 10 Countries')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Release Year

# %% [markdown]
# Distribution Show the more movie and TVshow is from 2010 to 2020

# %%
data['release_year'].plot(kind='hist', bins=30)
plt.title('Distribution of Release Years')
plt.xlabel('Release Year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Category

# %%
category = data.groupby(['category', 'type'])['category'].value_counts().reset_index()
category
# Out:
#                                               category     type  count
# 0                                   Action & Adventure    Movie    128
# 1                   Action & Adventure, Anime Features    Movie      1
# 2    Action & Adventure, Anime Features, Children &...    Movie      4
# 3    Action & Adventure, Anime Features, Classic Mo...    Movie      2
# 4    Action & Adventure, Anime Features, Horror Movies    Movie      1
# ..                                                 ...      ...    ...
# 508             TV Horror, TV Mysteries, Teen TV Shows  TV Show      1
# 509                           TV Horror, Teen TV Shows  TV Show      2
# 510                  TV Sci-Fi & Fantasy, TV Thrillers  TV Show      1
# 511                                           TV Shows  TV Show     16
# 512                                          Thrillers    Movie     65
#
# [513 rows x 3 columns]

# %%
top_10_listed_in_movie = category[category['type'] == 'Movie'].sort_values(by='count', ascending=False).iloc[0:10]
top_10_listed_in_movie
# Out:
#                                              category   type  count
# 325                      Dramas, International Movies  Movie    362
# 273                                     Documentaries  Movie    359
# 469                                   Stand-Up Comedy  Movie    334
# 199            Comedies, Dramas, International Movies  Movie    274
# 318  Dramas, Independent Movies, International Movies  Movie    252
# 120                          Children & Family Movies  Movie    215
# 124                Children & Family Movies, Comedies  Movie    201
# 280               Documentaries, International Movies  Movie    186
# 328     Dramas, International Movies, Romantic Movies  Movie    180
# 216                    Comedies, International Movies  Movie    176

# %%
top_10_listed_in_movie.plot(x='category', y='count', kind='bar')
plt.title('Top 10 Listed Genres for Movies')
plt.xlabel('Genre')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()
